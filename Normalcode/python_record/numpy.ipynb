# %%
import pandas as pd
data = {"Name": ["Anand", "Akhil", "Anand", "Akhil","Anand", "Akhil"], "Age": [18 , 17, 18 , 17, 18 , 17]}
df = pd.DataFrame(data)
print(df)

# %%
import numpy as np
arr = np.array([0,1,2,3,2225])
print(arr*2)
print("Mean of the array", np.mean(arr))
print(np.max(arr))
a = np.linspace(0, 10, num=100, dtype=np.int64)
print(a)

# %%
import numpy as np
x = np.array([[1, 2], [3, 4]])
y = np.array([[5, 6]])
np.concatenate((x, y))

# %%
import matplotlib.pyplot as plt
x = [1, 4, 9, 16, 25]
y = [3, 5, 7, 9, 11]
plt.plot(x)
plt.show()

# %%
array_example = np.array([[[0, 1, 2, 3],
                           [4, 5, 6, 7]],

                          [[0, 1, 2, 3],
                           [4, 5, 6, 7]],

                          [[0 ,1 ,2, 3],
                           [4, 5, 6, 7]]])

siz = array_example.ndim
print("Number of dimensions:", siz)
# Out:
# Number of dimensions: 3
